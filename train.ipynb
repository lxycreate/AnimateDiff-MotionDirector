# %%
# !git clone https://github.com/lxycreate/AnimateDiff-MotionDirector

# %cd AnimateDiff-MotionDirector
# !pip install --upgrade pip setuptools wheel
# !pip install tokenizers==0.13.3
# !pip install -r requirements.txt
